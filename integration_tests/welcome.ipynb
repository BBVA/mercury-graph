# %%
HOST = 'http://0.0.0.0'
PORT = '8765'
URL  = '%s:%s' % (HOST, PORT)

# %%
from mercury.graph.evidence.remote import RemoteEndpoint

# %%
ep = RemoteEndpoint(URL)

# %%
ep.functions

# %%
ep.run('children_by_idx_mediawiki_example', '')

# %%
ep.run('children_by_idx_pdf_example', '')

# %%
ep.run('children_by_idx_md_example', '')

# %%
text = 'Siemens is bidding to build a powerstation in Dubai against American and Japanese companies. Last Wednesday Total Energies decided to quit the race as stated by its CEO Jean Dupont.'

text

# %%
ep.run('hint_nodes_GLiNER2', {'text' : text})

# %%
ep.run('hint_nodes_GLiNER2', {'text' : text, 'concepts' : ['city_in_UAE', 'french_company']})

# %%
ep.run('hint_edges_GLiNER2', {'text' : text})

# %%
ep.run('chat_with_gru', 'One word, what is the capital of France?')

# %%
# children_by_idx_russell

text = """

Ok, Gru,

You have access to a tool called children_by_idx_pdf_example, you can call it with an empty index to find out what the indices at the top are.

Call it just once and give me one of the indices chosen at random.
"""

ep.run('chat_with_gru', text)
